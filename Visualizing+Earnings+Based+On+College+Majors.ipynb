# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
recent_grads.head()
recent_grads.tail()
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = 173
recent_grads = recent_grads.dropna()

# %%
recent_grads.describe()
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
cleaned_data_count = 172

# %%
ax1 = recent_grads.plot(x='Sample_size',y='Median',kind='scatter')
ax1.set_title("Sample_size vs Median")

# %%
ax2 = recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')
ax2.set_title("Sample_size vs Unemloyment_rate")

# %%
ax3 = recent_grads.plot(x='Full_time',y='Median',kind='scatter')
ax3.set_title("Full_time vs Median")

# %%
ax4 = recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')
ax4.set_title("ShareWomen vs. Unemployment_rate")

# %%
ax5 = recent_grads.plot(x='Men',y='Median',kind='scatter')
ax5.set_title("Men vs Median")

# %%
ax6 = recent_grads.plot(x='Women',y='Median',kind='scatter')
ax6.set_title("Women vs Median")

# %% [markdown]
# # Observations
# ----------Do students in more popular majors make more money?
# # Not necessarily,highest median salaries in less popular ones.
# ----------Do students that majored in subjects that were majority female make more money?
# # Some do.not necessary.no correlation
# -------Is there any link between the number of full-time employees and median salary?
# # Yes. with more fulltime employees the median salaries seem to have a narrow range. The highest median salaries are observed in majorss with less full-time employees

# %%
recent_grads["Sample_size"].value_counts().sort_index()
# Out:
# 2       1
# 3       2
# 4       3
# 5       2
# 7       3
# 8       1
# 9       1
# 10      2
# 11      1
# 13      1
# 14      1
# 16      1
# 17      1
# 18      1
# 21      1
# 22      3
# 24      2
# 25      1
# 26      2
# 28      1
# 29      1
# 30      2
# 31      2
# 32      1
# 36      2
# 37      2
# 38      1
# 39      1
# 43      1
# 44      1
#        ..
# 541     1
# 546     1
# 565     1
# 569     1
# 590     1
# 623     1
# 631     1
# 681     1
# 843     1
# 919     1
# 1014    1
# 1024    1
# 1029    1
# 1058    1
# 1186    1
# 1196    1
# 1322    1
# 1370    1
# 1387    1
# 1436    1
# 1629    1
# 1728    1
# 2042    1
# 2189    1
# 2380    1
# 2394    1
# 2554    1
# 2584    1
# 2684    1
# 4212    1
# Name: Sample_size, Length: 147, dtype: int64

# %%
recent_grads["Sample_size"].hist(bins=20)

# %%
recent_grads["Median"].hist(bins=20)

# %% [markdown]
# # Median Salary range of 30-35k is most common

# %%
recent_grads["Employed"].hist(bins=20)

# %%
recent_grads["Full_time"].hist(bins=10)

# %%
recent_grads["ShareWomen"].hist(bins=5)

# %% [markdown]
# # Around 45% majors have more than 60% female grads. Obviously, 55% have less than that.More majors are female dominant.

# %%
recent_grads["Unemployment_rate"].hist(bins=20)

# %%
recent_grads["Men"].hist(bins=5)

# %%
recent_grads["Women"].hist(bins=5)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8bfa276a20>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8bfa07c198>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["ShareWomen","Median"]],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8bf9cd9e80>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[cleaned_data_count - 10: cleaned_data_count].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[cleaned_data_count - 10: cleaned_data_count].plot.bar(x='Major', y='Unemployment_rate')
